# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd

plt.close("all")

# %%
np.random.seed(123456)

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts
# Out:
# 2000-01-01    0.469112
# 2000-01-02   -0.282863
# 2000-01-03   -1.509059
# 2000-01-04   -1.135632
# 2000-01-05    1.212112
#                 ...
# 2002-09-22   -1.512743
# 2002-09-23    0.933753
# 2002-09-24   -0.308013
# 2002-09-25   -0.079915
# 2002-09-26   -1.010589
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2000-01-01     0.469112
# 2000-01-02     0.186249
# 2000-01-03    -1.322810
# 2000-01-04    -2.458442
# 2000-01-05    -1.246330
#                 ...
# 2002-09-22   -45.579481
# 2002-09-23   -44.645728
# 2002-09-24   -44.953742
# 2002-09-25   -45.033657
# 2002-09-26   -46.044246
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.218470 -0.061645 -0.723780  0.551225
# 2000-01-02 -0.497767  0.837519  1.103245 -1.118384
# 2000-01-03 -0.542980 -0.994002  1.508742 -0.328697
# 2000-01-04 -0.562235  0.001596  0.077546  0.989734
# 2000-01-05 -1.692654  0.473952 -0.689182  0.598385
# ...              ...       ...       ...       ...
# 2002-09-22 -2.121763  0.219337  0.035556  0.023718
# 2002-09-23 -0.215193  0.229842 -0.431127 -0.296778
# 2002-09-24  0.161365 -2.171121 -0.492110 -0.984204
# 2002-09-25 -0.737258 -1.112252  1.453585  1.633952
# 2002-09-26 -0.234109  0.814500  0.249707 -1.418041
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df
# Out:
#                     A         B         C          D
# 2000-01-01  -0.218470 -0.061645 -0.723780   0.551225
# 2000-01-02  -0.716236  0.775873  0.379465  -0.567160
# 2000-01-03  -1.259217 -0.218128  1.888207  -0.895857
# 2000-01-04  -1.821452 -0.216532  1.965752   0.093877
# 2000-01-05  -3.514107  0.257420  1.276571   0.692263
# ...               ...       ...       ...        ...
# 2002-09-22 -18.386466  2.243464  2.938592  40.416305
# 2002-09-23 -18.601660  2.473306  2.507465  40.119526
# 2002-09-24 -18.440294  0.302185  2.015355  39.135322
# 2002-09-25 -19.177552 -0.810066  3.468941  40.769274
# 2002-09-26 -19.411661  0.004433  3.718648  39.351233
#
# [1000 rows x 4 columns]

# %%
plt.figure();

# %%
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3
# Out:
#              B         C
# 0     0.879831  0.573687
# 1     0.145896  0.149091
# 2     1.782761  1.397438
# 3    -0.038807  2.758431
# 4     0.232905  2.468640
# ..         ...       ...
# 995 -27.673706 -3.591743
# 996 -29.459943 -3.306978
# 997 -27.398674 -2.735528
# 998 -29.589450 -2.312671
# 999 -29.733052 -3.633835
#
# [1000 rows x 2 columns]

# %%
df3["A"] = pd.Series(list(range(len(df))))
df3
# Out:
#              B         C    A
# 0     0.879831  0.573687    0
# 1     0.145896  0.149091    1
# 2     1.782761  1.397438    2
# 3    -0.038807  2.758431    3
# 4     0.232905  2.468640    4
# ..         ...       ...  ...
# 995 -27.673706 -3.591743  995
# 996 -29.459943 -3.306978  996
# 997 -27.398674 -2.735528  997
# 998 -29.589450 -2.312671  998
# 999 -29.733052 -3.633835  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A", y="B");

# %%
df.iloc[5]
# Out:
# A   -3.689192
# B    1.297722
# C    2.265614
# D    2.318966
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
plt.figure();

df.iloc[5].plot(kind="bar");

# %%
plt.figure();

df.iloc[5].plot.bar();

plt.axhline(0, color="k");

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2
# Out:
#           a         b         c         d
# 0  0.776756  0.303773  0.428600  0.070400
# 1  0.249213  0.973558  0.404596  0.777473
# 2  0.644560  0.022563  0.444410  0.804606
# 3  0.628325  0.398168  0.082784  0.099393
# 4  0.401857  0.090636  0.886385  0.424656
# 5  0.622205  0.739249  0.041461  0.933507
# 6  0.231107  0.292615  0.883645  0.695019
# 7  0.608669  0.280347  0.484302  0.625539
# 8  0.568170  0.254995  0.621211  0.385128
# 9  0.506793  0.926615  0.970202  0.308848

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df4 = pd.DataFrame(

    {

        "a": np.random.randn(1000) + 1,

        "b": np.random.randn(1000),

        "c": np.random.randn(1000) - 1,

    },

    columns=["a", "b", "c"],

)


df4
# Out:
#             a         b         c
# 0    1.717808  1.600283 -0.854723
# 1    0.099041 -0.605731 -0.691854
# 2    2.180217 -0.561047 -2.043530
# 3   -0.297617  0.387419 -1.708145
# 4    0.868325 -0.837884  0.430905
# ..        ...       ...       ...
# 995 -0.869881  1.618922 -2.062384
# 996 -1.079393 -1.424723 -0.181155
# 997 -0.471215 -0.023232 -0.975853
# 998  1.426664  0.948196  0.441112
# 999  1.119476  0.183573 -1.661444
#
# [1000 rows x 3 columns]

# %%
plt.figure();

df4.plot.hist(alpha=0.5);

# %%
plt.figure();

df4.plot.hist(stacked=True, bins=20);

# %%
plt.figure();

df4.plot.hist(stacked=True);

# %%
plt.figure();

df4["a"].plot.hist(orientation="horizontal", cumulative=True);

# %%
plt.figure();

df4["a"].plot.hist(orientation="vertical", cumulative=True);

# %%
df["A"].diff()
# Out:
# 2000-01-01         NaN
# 2000-01-02   -0.497767
# 2000-01-03   -0.542980
# 2000-01-04   -0.562235
# 2000-01-05   -1.692654
#                 ...
# 2002-09-22   -2.121763
# 2002-09-23   -0.215193
# 2002-09-24    0.161365
# 2002-09-25   -0.737258
# 2002-09-26   -0.234109
# Freq: D, Name: A, Length: 1000, dtype: float64

# %%
plt.figure();

df["A"].diff().hist();

# %%
plt.figure();

df.hist();

# %%
plt.figure();

df.diff().hist(color="k", alpha=0.5, bins=50);

# %%
data = pd.Series(np.random.randn(1000))

data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
df.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
data = pd.DataFrame(

    {

        "a": np.random.choice(["x", "y", "z"], 1000),

        "b": np.random.choice(["e", "f", "g"], 1000),

        "c": np.random.randn(1000),

        "d": np.random.randn(1000) - 1,

    },

)

data
# Out:
#      a  b         c         d
# 0    z  e  0.455674 -1.235043
# 1    z  e  2.571061 -1.896222
# 2    y  f -1.152538  1.487351
# 3    y  g -1.638940 -1.969449
# 4    z  g -0.364831 -1.860462
# ..  .. ..       ...       ...
# 995  x  e  1.187378 -0.712211
# 996  z  e -0.339398 -0.740268
# 997  x  e  1.526317  0.001529
# 998  y  f -0.509733  0.495983
# 999  z  e -0.633944 -0.472982
#
# [1000 rows x 4 columns]

# %%
data.plot.hist(by=["a", "b"], figsize=(10, 5));

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0  0.221855  0.485524  0.475368  0.919226  0.058456
# 1  0.400810  0.015498  0.672895  0.012098  0.204518
# 2  0.773243  0.033629  0.436641  0.957531  0.684440
# 3  0.269626  0.407319  0.590351  0.932317  0.876217
# 4  0.427266  0.835188  0.307563  0.277375  0.447331
# 5  0.555787  0.698982  0.259623  0.443054  0.883142
# 6  0.585036  0.049161  0.141522  0.010461  0.684090
# 7  0.973270  0.104224  0.646473  0.919409  0.589041
# 8  0.250939  0.775977  0.107914  0.098277  0.112038
# 9  0.873971  0.451953  0.115506  0.408628  0.309948

# %%
df.plot.box();

# %%
color = {

    "boxes": "DarkGreen",

    "whiskers": "DarkOrange",

    "medians": "DarkBlue",

    "caps": "Gray",

}



df.plot.box(color=color, sym="r+");

# %%
df.plot.box(vert=False, positions=[2, 4, 5, 7, 8]);

# %%
df = pd.DataFrame(np.random.rand(10, 5))
df
# Out:
#           0         1         2         3         4
# 0  0.984441  0.970530  0.427346  0.361248  0.484612
# 1  0.439503  0.478454  0.365116  0.045190  0.719950
# 2  0.886748  0.120180  0.464374  0.841948  0.477800
# 3  0.672238  0.768474  0.575327  0.964833  0.124666
# 4  0.106948  0.867328  0.191213  0.008358  0.426706
# 5  0.438425  0.404215  0.228118  0.784908  0.820251
# 6  0.335371  0.191137  0.128071  0.797033  0.334973
# 7  0.861879  0.650944  0.193704  0.311921  0.222659
# 8  0.992042  0.052687  0.642692  0.249451  0.273894
# 9  0.707204  0.097240  0.911776  0.056491  0.836607

# %%
plt.figure();

bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])
df
# Out:
#        Col1      Col2
# 0  0.510764  0.188341
# 1  0.733740  0.467880
# 2  0.032076  0.781026
# 3  0.366745  0.647656
# 4  0.526996  0.725953
# 5  0.256453  0.935288
# 6  0.301503  0.110811
# 7  0.921589  0.632282
# 8  0.990403  0.478865
# 9  0.729958  0.236539

# %%
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
df
# Out:
#        Col1      Col2  X
# 0  0.510764  0.188341  A
# 1  0.733740  0.467880  A
# 2  0.032076  0.781026  A
# 3  0.366745  0.647656  A
# 4  0.526996  0.725953  A
# 5  0.256453  0.935288  B
# 6  0.301503  0.110811  B
# 7  0.921589  0.632282  B
# 8  0.990403  0.478865  B
# 9  0.729958  0.236539  B

# %%
plt.figure();

bp = df.boxplot(by="X")

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])
df
# Out:
#        Col1      Col2      Col3
# 0  0.245884  0.620022  0.020079
# 1  0.592172  0.727346  0.416172
# 2  0.162781  0.605095  0.651882
# 3  0.017776  0.702667  0.647544
# 4  0.646367  0.919271  0.285613
# 5  0.197888  0.497577  0.920549
# 6  0.141530  0.162168  0.956292
# 7  0.048350  0.188853  0.231930
# 8  0.578690  0.611860  0.062776
# 9  0.931640  0.191907  0.888714

# %%
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])

df["Y"] = pd.Series(["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"])

df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.245884  0.620022  0.020079  A  A
# 1  0.592172  0.727346  0.416172  A  B
# 2  0.162781  0.605095  0.651882  A  A
# 3  0.017776  0.702667  0.647544  A  B
# 4  0.646367  0.919271  0.285613  A  A
# 5  0.197888  0.497577  0.920549  B  B
# 6  0.141530  0.162168  0.956292  B  A
# 7  0.048350  0.188853  0.231930  B  B
# 8  0.578690  0.611860  0.062776  B  A
# 9  0.931640  0.191907  0.888714  B  B

# %%
plt.figure();

bp = df.boxplot(column=["Col1", "Col2"], by=["X", "Y"])

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])
df
# Out:
#        Col1      Col2      Col3
# 0  0.670275  0.485410  0.578274
# 1  0.208282  0.277517  0.905007
# 2  0.851041  0.979401  0.169873
# 3  0.498221  0.112589  0.980535
# 4  0.318659  0.960689  0.893877
# 5  0.183383  0.386928  0.572814
# 6  0.766455  0.432969  0.701396
# 7  0.794422  0.647051  0.373447
# 8  0.650863  0.093372  0.771913
# 9  0.229239  0.853000  0.333530

# %%
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
df
# Out:
#        Col1      Col2      Col3  X
# 0  0.670275  0.485410  0.578274  A
# 1  0.208282  0.277517  0.905007  A
# 2  0.851041  0.979401  0.169873  A
# 3  0.498221  0.112589  0.980535  A
# 4  0.318659  0.960689  0.893877  A
# 5  0.183383  0.386928  0.572814  B
# 6  0.766455  0.432969  0.701396  B
# 7  0.794422  0.647051  0.373447  B
# 8  0.650863  0.093372  0.771913  B
# 9  0.229239  0.853000  0.333530  B

# %%
plt.figure();

bp = df.plot.box(column=["Col1", "Col2"], by="X")

# %%
np.random.seed(1234)

df_box = pd.DataFrame(np.random.randn(50, 2))

df_box.head()
# Out:
#           0         1
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 2 -0.720589  0.887163
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685

# %%
df_box["g"] = np.random.choice(["A", "B"], size=50)
df_box.head()
# Out:
#           0         1  g
# 0  0.471435 -1.190976  A
# 1  1.432707 -0.312652  A
# 2 -0.720589  0.887163  B
# 3  0.859588 -0.636524  A
# 4  0.015696 -2.242685  B

# %%
df_box.loc[df_box["g"] == "B", 1] += 3

bp = df_box.boxplot(by="g")

# %%
bp = df_box.groupby("g").boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195
# 5  0.889963  0.993567  0.818704  0.545122
# 6  0.451254  0.890557  0.973265  0.593411
# 7  0.366074  0.323095  0.871423  0.215634
# 8  0.734945  0.365619  0.801603  0.782736
# 9  0.701355  0.622777  0.493683  0.840538

# %%
df.plot.area();

# %%
df.plot.area(stacked=False);

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])

df.head(10)
# Out:
#           a         b         c         d
# 0  0.712097  0.443909  0.031035  0.363240
# 1  0.730722  0.475567  0.344417  0.640880
# 2  0.126205  0.171465  0.737086  0.127029
# 3  0.369650  0.604334  0.103104  0.802374
# 4  0.945553  0.979039  0.881232  0.627682
# 5  0.930487  0.724790  0.716678  0.041079
# 6  0.439482  0.282070  0.334996  0.083527
# 7  0.760849  0.509272  0.661047  0.630314
# 8  0.370927  0.446740  0.415108  0.480389
# 9  0.983324  0.373424  0.012407  0.921903

# %%
df["species"] = pd.Categorical(

    ["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10

)
df.head(10)
# Out:
#           a         b         c         d species
# 0  0.712097  0.443909  0.031035  0.363240  setosa
# 1  0.730722  0.475567  0.344417  0.640880  setosa
# 2  0.126205  0.171465  0.737086  0.127029  setosa
# 3  0.369650  0.604334  0.103104  0.802374  setosa
# 4  0.945553  0.979039  0.881232  0.627682  setosa
# 5  0.930487  0.724790  0.716678  0.041079  setosa
# 6  0.439482  0.282070  0.334996  0.083527  setosa
# 7  0.760849  0.509272  0.661047  0.630314  setosa
# 8  0.370927  0.446740  0.415108  0.480389  setosa
# 9  0.983324  0.373424  0.012407  0.921903  setosa

# %%
df.plot.scatter(x="a", y="b");

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")

df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=ax);

# %%
df.plot.scatter(x="a", y="b", c="c", s=50);

# %%
df.plot.scatter(x="a", y="b", c="species", cmap="viridis", s=50);

# %%
df.plot.scatter(x="a", y="b", s=df["c"] * 200);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])

df["b"] = df["b"] + np.arange(1000)

df.plot.hexbin(x="a", y="b", gridsize=25);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])

df["b"] = df["b"] + np.arange(1000)

df["z"] = np.random.uniform(0, 3, 1000)

df.plot.hexbin(x="a", y="b", C="z", reduce_C_function=np.max, gridsize=25);

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series
# Out:
# a    0.855593
# b    2.177081
# c    1.786922
# d    1.659012
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6));

# %%
df = pd.DataFrame(

    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]

)
df
# Out:
#           x         y
# a  1.703954  2.144225
# b  0.409211  0.978524
# c  0.143561  0.327329
# d  0.918073  2.211757

# %%
df.plot.pie(subplots=True, figsize=(8, 4));

# %%
series
# Out:
# a    0.855593
# b    2.177081
# c    1.786922
# d    1.659012
# Name: series, dtype: float64

# %%
series.plot.pie(

    labels=["AA", "BB", "CC", "DD"],

    colors=["r", "g", "b", "c"],

    autopct="%.2f",

    fontsize=20,

    figsize=(6, 6),

);

# %%
series = pd.Series([0.1] * 4, index=["a", "b", "c", "d"], name="series2")

series.plot.pie(figsize=(6, 6));

# %%
from pandas.plotting import scatter_matrix

df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.504953  2.532520 -0.241684 -0.742253
# 1 -0.939005 -2.600098 -1.221314 -1.967797
# 2  0.369079  0.319504  0.557210 -0.223116
# 3  0.912469  1.801429  0.527591  0.672056
# 4  0.041438 -1.729341  1.372180  0.305236
# 5 -1.880589 -1.066323  2.228689  0.512232
# 6 -0.812381 -0.175391  1.408653  0.848417
# 7 -0.988591 -1.225316  0.837066 -0.867702
# 8  0.553156  0.376529  1.296955 -0.046883
# 9 -1.390954  0.822168 -1.553026 -1.035586

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde");

# %%
ser = pd.Series(np.random.randn(1000))

ser.plot.kde();

# %%
from pandas.plotting import andrews_curves

from sklearn.datasets import load_iris

iris = load_iris()

data = pd.DataFrame(iris['data'], columns=["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"])

target = iris['target']

target_names = iris['target_names']

data["Name"] = pd.Series(target).map({0: target_names[0], 1: target_names[1], 2: target_names[2]})

data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth       Name
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure();

andrews_curves(data, "Name");

# %%
from pandas.plotting import parallel_coordinates

plt.figure();

parallel_coordinates(data, "Name");

# %%
from pandas.plotting import lag_plot

plt.figure();

spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)

data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))

lag_plot(data);

# %%
from pandas.plotting import autocorrelation_plot

plt.figure();

spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)

data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(spacing))

autocorrelation_plot(data);

# %%
from pandas.plotting import bootstrap_plot

data = pd.Series(np.random.rand(1000))

data.head(10)
# Out:
# 0    0.563765
# 1    0.226680
# 2    0.073032
# 3    0.145995
# 4    0.386632
# 5    0.435494
# 6    0.414442
# 7    0.047158
# 8    0.824575
# 9    0.889065
# dtype: float64

# %%
bootstrap_plot(data, size=50, samples=500, color="grey");

# %%
data = pd.DataFrame(iris['data'], columns=["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"])

target = iris['target']

target_names = iris['target_names']

data["Name"] = pd.Series(target).map({0: target_names[0], 1: target_names[1], 2: target_names[2]})

# %%
from pandas.plotting import radviz

plt.figure();

radviz(data, "Name");

# %%
import matplotlib
matplotlib.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure();

ts.head()
# Out:
# 2000-01-01    0.469112
# 2000-01-02    0.186249
# 2000-01-03   -1.322810
# 2000-01-04   -2.458442
# 2000-01-05   -1.246330
# Freq: D, dtype: float64

# %%
ts.plot(style="k--", label="Series");

# %%
ts.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))

df = df.cumsum()

df.plot(legend=False);

# %%
df.plot(legend=True);

# %%
df.plot();

df.plot(xlabel="new x", ylabel="new y");

# %%
ts1 = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts2 = np.exp(ts1.cumsum())

ts1.head()
# Out:
# 2000-01-01    0.058350
# 2000-01-02   -0.063544
# 2000-01-03   -0.201107
# 2000-01-04   -0.948918
# 2000-01-05    1.629646
# Freq: D, dtype: float64

# %%
ts2.plot(logy=False);

# %%
ts2.plot(logy=True);

# %%
df["A"].plot();

# %%
df["B"].plot(secondary_y=True, style="g");

# %%
df["A"].plot();
df["B"].plot(secondary_y=True, style="g");

# %%
plt.figure();

ax = df.plot(secondary_y=["A", "B"])

ax.set_ylabel("CD scale");

ax.right_ax.set_ylabel("AB scale");

# %%
plt.figure();

df["A"].plot();

# %%
plt.figure();

df["A"].plot(x_compat=True);

# %%
plt.figure();

with pd.plotting.plot_params.use("x_compat", True):

    df["A"].plot(color="r")

    df["B"].plot(color="g")

    df["C"].plot(color="b")

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False);

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(6, 6), sharex=False);

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 9))

plt.subplots_adjust(wspace=0.5, hspace=0.5)

target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]

target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]

df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False);

(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False);

# %%
np.random.seed(123456)

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))

df = df.cumsum()

df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.218470 -0.061645 -0.723780  0.551225
# 2000-01-02 -0.716236  0.775873  0.379465 -0.567160
# 2000-01-03 -1.259217 -0.218128  1.888207 -0.895857
# 2000-01-04 -1.821452 -0.216532  1.965752  0.093877
# 2000-01-05 -3.514107  0.257420  1.276571  0.692263

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

plt.subplots_adjust(wspace=0.2, hspace=0.5)

df["A"].plot(ax=axes[0, 0]);

axes[0, 0].set_title("A");

df["B"].plot(ax=axes[0, 1]);

axes[0, 1].set_title("B");

df["C"].plot(ax=axes[1, 0]);

axes[1, 0].set_title("C");

df["D"].plot(ax=axes[1, 1]);

axes[1, 1].set_title("D");

# %%
# Generate the data

ix3 = pd.MultiIndex.from_arrays(

    [

        ["a", "a", "a", "a", "a", "b", "b", "b", "b", "b"],

        ["foo", "foo", "foo", "bar", "bar", "foo", "foo", "bar", "bar", "bar"],

    ],

    names=["letter", "word"],

)



df3 = pd.DataFrame(

    {

        "data1": [9, 3, 2, 4, 3, 2, 4, 6, 3, 2],

        "data2": [9, 6, 5, 7, 5, 4, 5, 6, 5, 1],

    },

    index=ix3,

)

df3
# Out:
#              data1  data2
# letter word
# a      foo       9      9
#        foo       3      6
#        foo       2      5
#        bar       4      7
#        bar       3      5
# b      foo       2      4
#        foo       4      5
#        bar       6      6
#        bar       3      5
#        bar       2      1

# %%
# Group by index labels and take the means and standard deviations
# for each group

gp3 = df3.groupby(level=("letter", "word"))

means = gp3.mean()

errors = gp3.std()

means
# Out:
#                 data1     data2
# letter word
# a      bar   3.500000  6.000000
#        foo   4.666667  6.666667
# b      bar   3.666667  4.000000
#        foo   3.000000  4.500000

# %%
errors
# Out:
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   3.785939  2.081666
# b      bar   2.081666  2.645751
#        foo   1.414214  0.707107

# %%
# Plot

fig, ax = plt.subplots()

means.plot.bar(yerr=errors, ax=ax, capsize=4, rot=0);

# %%
mins = gp3.min()

maxs = gp3.max()

# errors should be positive, and defined in the order of lower, upper

errors = [[means[c] - mins[c], maxs[c] - means[c]] for c in df3.columns]

# %%
mins.shape
# Out:
# (4, 2)

# %%
means.shape
# Out:
# (4, 2)

# %%
fig, ax = plt.subplots()

means.plot.bar(yerr=errors, ax=ax, capsize=4, rot=0);

# %%
np.random.seed(123456)

df = pd.DataFrame(np.random.rand(5, 3), columns=["a", "b", "c"])

df.head()
# Out:
#           a         b         c
# 0  0.126970  0.966718  0.260476
# 1  0.897237  0.376750  0.336222
# 2  0.451376  0.840255  0.123102
# 3  0.543026  0.373012  0.447997
# 4  0.129441  0.859879  0.820388

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.5))

ax.xaxis.tick_top()  # Display x-axis ticks on top.

df.plot(table=True, ax=ax);

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.75))

ax.xaxis.tick_top()  # Display x-axis ticks on top.

df.plot(table=np.round(df.T, 2), ax=ax);

# %%
from pandas.plotting import table

fig, ax = plt.subplots(1, 1)

table(ax, np.round(df.describe(), 2), loc="upper right", colWidths=[0.2, 0.2, 0.2]);

df.plot(ax=ax, ylim=(0, 2), legend=None);

# %%
np.random.seed(123456)

df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)

df = df.cumsum()

plt.figure();

df.plot(colormap="cubehelix");

# %%
from matplotlib import cm

plt.figure();

df.plot(colormap=cm.cubehelix);

# %%
np.random.seed(123456)

dd = pd.DataFrame(np.random.randn(10, 10)).map(abs)

dd = dd.cumsum()

plt.figure();

dd.plot.bar(colormap="Greens");

# %%
plt.figure();

parallel_coordinates(data, "Name", colormap="gist_rainbow");

# %%
plt.figure();

andrews_curves(data, "Name", colormap="winter");

# %%
np.random.seed(123456)

price = pd.Series(

    np.random.randn(150).cumsum(),

    index=pd.date_range("2000-1-1", periods=150, freq="B"),

)



ma = price.rolling(20).mean()

mstd = price.rolling(20).std()

# %%
plt.figure();

plt.plot(price.index, price, "k");

plt.plot(ma.index, ma, "b");

plt.fill_between(mstd.index, ma - 2 * mstd, ma + 2 * mstd, color="b", alpha=0.2);
