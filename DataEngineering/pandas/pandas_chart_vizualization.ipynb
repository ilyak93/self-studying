# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd

plt.close("all")

# %%
np.random.seed(123456)

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts
# Out:
# 2000-01-01    0.469112
# 2000-01-02   -0.282863
# 2000-01-03   -1.509059
# 2000-01-04   -1.135632
# 2000-01-05    1.212112
#                 ...
# 2002-09-22   -1.512743
# 2002-09-23    0.933753
# 2002-09-24   -0.308013
# 2002-09-25   -0.079915
# 2002-09-26   -1.010589
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2000-01-01     0.469112
# 2000-01-02     0.186249
# 2000-01-03    -1.322810
# 2000-01-04    -2.458442
# 2000-01-05    -1.246330
#                 ...
# 2002-09-22   -45.579481
# 2002-09-23   -44.645728
# 2002-09-24   -44.953742
# 2002-09-25   -45.033657
# 2002-09-26   -46.044246
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.218470 -0.061645 -0.723780  0.551225
# 2000-01-02 -0.497767  0.837519  1.103245 -1.118384
# 2000-01-03 -0.542980 -0.994002  1.508742 -0.328697
# 2000-01-04 -0.562235  0.001596  0.077546  0.989734
# 2000-01-05 -1.692654  0.473952 -0.689182  0.598385
# ...              ...       ...       ...       ...
# 2002-09-22 -2.121763  0.219337  0.035556  0.023718
# 2002-09-23 -0.215193  0.229842 -0.431127 -0.296778
# 2002-09-24  0.161365 -2.171121 -0.492110 -0.984204
# 2002-09-25 -0.737258 -1.112252  1.453585  1.633952
# 2002-09-26 -0.234109  0.814500  0.249707 -1.418041
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df
# Out:
#                     A         B         C          D
# 2000-01-01  -0.218470 -0.061645 -0.723780   0.551225
# 2000-01-02  -0.716236  0.775873  0.379465  -0.567160
# 2000-01-03  -1.259217 -0.218128  1.888207  -0.895857
# 2000-01-04  -1.821452 -0.216532  1.965752   0.093877
# 2000-01-05  -3.514107  0.257420  1.276571   0.692263
# ...               ...       ...       ...        ...
# 2002-09-22 -18.386466  2.243464  2.938592  40.416305
# 2002-09-23 -18.601660  2.473306  2.507465  40.119526
# 2002-09-24 -18.440294  0.302185  2.015355  39.135322
# 2002-09-25 -19.177552 -0.810066  3.468941  40.769274
# 2002-09-26 -19.411661  0.004433  3.718648  39.351233
#
# [1000 rows x 4 columns]

# %%
plt.figure();

# %%
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3
# Out:
#              B         C
# 0     0.879831  0.573687
# 1     0.145896  0.149091
# 2     1.782761  1.397438
# 3    -0.038807  2.758431
# 4     0.232905  2.468640
# ..         ...       ...
# 995 -27.673706 -3.591743
# 996 -29.459943 -3.306978
# 997 -27.398674 -2.735528
# 998 -29.589450 -2.312671
# 999 -29.733052 -3.633835
#
# [1000 rows x 2 columns]

# %%
df3["A"] = pd.Series(list(range(len(df))))
df3
# Out:
#              B         C    A
# 0     0.879831  0.573687    0
# 1     0.145896  0.149091    1
# 2     1.782761  1.397438    2
# 3    -0.038807  2.758431    3
# 4     0.232905  2.468640    4
# ..         ...       ...  ...
# 995 -27.673706 -3.591743  995
# 996 -29.459943 -3.306978  996
# 997 -27.398674 -2.735528  997
# 998 -29.589450 -2.312671  998
# 999 -29.733052 -3.633835  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A", y="B");

# %%
df.iloc[5]
# Out:
# A   -3.689192
# B    1.297722
# C    2.265614
# D    2.318966
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
plt.figure();

df.iloc[5].plot(kind="bar");

# %%
plt.figure();

df.iloc[5].plot.bar();

plt.axhline(0, color="k");

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2
# Out:
#           a         b         c         d
# 0  0.776756  0.303773  0.428600  0.070400
# 1  0.249213  0.973558  0.404596  0.777473
# 2  0.644560  0.022563  0.444410  0.804606
# 3  0.628325  0.398168  0.082784  0.099393
# 4  0.401857  0.090636  0.886385  0.424656
# 5  0.622205  0.739249  0.041461  0.933507
# 6  0.231107  0.292615  0.883645  0.695019
# 7  0.608669  0.280347  0.484302  0.625539
# 8  0.568170  0.254995  0.621211  0.385128
# 9  0.506793  0.926615  0.970202  0.308848

# %%
df2.plot.bar();
